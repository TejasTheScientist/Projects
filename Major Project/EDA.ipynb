# %% [markdown]
# ## <center>EDA</center>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
import_data = pd.read_csv("./clean_data.csv")
import_data.head()
# Out:
#                    Job Title Salary Estimate  \
# 0             Data Scientist           53-91
# 1  Healthcare Data Scientist          63-112
# 2             Data Scientist           80-90
# 3             Data Scientist           56-97
# 4             Data Scientist          86-143
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company Name     Location Headquarters  \
# 0                      Tecolote Research  Albuquerque       Goleta
# 1  University of Maryland Medical System    Linthicum    Baltimore
# 2                                KnowBe4   Clearwater   Clearwater
# ...

# %%
data = import_data.copy()
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Per hour', 'Min Salary', 'Max Salary', 'Avg Salary', 'Same place',
#        'age', 'Python', 'Power bi', 'Excel', 'Aws', 'Title', 'position',
#        'num_compi'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          742 non-null    object
#  1   Salary Estimate    742 non-null    object
#  2   Job Description    742 non-null    object
#  3   Rating             742 non-null    float64
#  4   Company Name       740 non-null    object
#  5   Location           742 non-null    object
#  6   Headquarters       741 non-null    object
#  7   Size               742 non-null    object
#  8   Founded            742 non-null    int64
#  9   Type of ownership  742 non-null    object
#  10  Industry           742 non-null    object
#  11  Sector             742 non-null    object
#  12  Revenue            742 non-null    object
#  13  Competitors        742 non-null    object
#  14  Per hour           742 non-null    int64
#  15  Min Salary         742 non-null    int64
# ...

# %%
data.describe().T
# Out:
#             count         mean         std   min     25%     50%     75%  \
# Rating      742.0     3.687342    0.566167   1.9     3.3     3.7     4.0
# Founded     742.0  1837.154987  497.183763  -1.0  1939.0  1988.0  2007.0
# Per hour    742.0     0.032345    0.177034   0.0     0.0     0.0     0.0
# Min Salary  742.0    74.719677   30.980593  15.0    52.0    69.5    91.0
# Max Salary  742.0   128.149596   45.220324  16.0    96.0   124.0   155.0
# Avg Salary  742.0   101.434636   37.546122  15.5    73.5    97.5   122.5
# Same place  742.0     0.557951    0.496965   0.0     0.0     1.0     1.0
# age         742.0   184.845013  497.183763   3.0    15.0    34.0    83.0
# Python      742.0     0.528302    0.499535   0.0     0.0     1.0     1.0
# Power bi    742.0     0.045822    0.209240   0.0     0.0     0.0     0.0
# Excel       742.0     0.522911    0.499812   0.0     0.0     1.0     1.0
# Aws         742.0     0.237197    0.425651   0.0     0.0     0.0     0.0
# ...

# %%
num_cols = ['Rating', 'Min Salary', 'Max Salary',
       'Avg Salary', 'Same place', 'Python', 'Power bi', 'Excel', 'Aws',
       'num_compi']
num_cols
# Out:
# ['Rating',
#  'Min Salary',
#  'Max Salary',
#  'Avg Salary',
#  'Same place',
#  'Python',
#  'Power bi',
#  'Excel',
#  'Aws',
#  'num_compi']

# %%
c = 0
plt.figure(figsize=(10,25))
for i in num_cols:
    c = c+1
    plt.subplot(5,2,c)
    sns.distplot(data[i])
    plt.title(i)
plt.show()

# %%
data.corr()
# Out:
#               Rating   Founded  Per hour  Min Salary  Max Salary  Avg Salary  \
# Rating      1.000000  0.112769 -0.049766    0.158483    0.106953    0.129791
# Founded     0.112769  1.000000  0.049313   -0.033999    0.006776   -0.009947
# Per hour   -0.049766  0.049313  1.000000   -0.203556   -0.276730   -0.250626
# Min Salary  0.158483 -0.033999 -0.203556    1.000000    0.940136    0.978714
# Max Salary  0.106953  0.006776 -0.276730    0.940136    1.000000    0.990066
# Avg Salary  0.129791 -0.009947 -0.250626    0.978714    0.990066    1.000000
# Same place  0.006520  0.171512 -0.067351   -0.051097   -0.032784   -0.040823
# age        -0.112769 -1.000000 -0.049313    0.033999   -0.006776    0.009947
# Python      0.164802  0.103183 -0.193487    0.326910    0.301481    0.316423
# Power bi    0.026547  0.036631 -0.040065   -0.009882   -0.024402   -0.018772
# Excel      -0.024115 -0.035567 -0.099897   -0.075234   -0.067175   -0.071492
# ...

# %%
corr_cols = ['Rating','Avg Salary', 'Same place', 'Python', 'Power bi', 'Excel', 'Aws','num_compi']

# %%
plt.figure(figsize = (12,9))
sns.heatmap(data[corr_cols].corr(), annot = True, cmap = 'Blues')
plt.show()

# %%
data.select_dtypes(include=object).columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Company Name',
#        'Location', 'Headquarters', 'Size', 'Type of ownership', 'Industry',
#        'Sector', 'Revenue', 'Competitors', 'Title', 'position'],
#       dtype='object')

# %%
cat_cols = [ 'Size', 'Type of ownership',
       'Sector', 'Revenue', 'Title']

# %%
# plt.figure(figsize=(15,10))
for i in cat_cols:

    sns.countplot(y = data[i])
    plt.title(i)

    plt.show()

# %%
data.groupby(['Title', 'position'])['Avg Salary'].mean().to_frame()
# Out:
#                          Avg Salary
# Title          position
# Data Analyst   Junior     53.250000
#                Senior     82.020833
#                na         61.402597
# Data Engineer  Senior    109.891892
#                na         99.538462
# Data Scientist Junior    106.500000
#                Senior    136.071429
#                na        109.608247
# ML Engineer    Senior    142.071429
#                na        119.133333
# Manager        na         84.022727
# na             Senior    113.234694
#                na         87.813492

# %%
data.groupby(['Location'])['Avg Salary'].mean().to_frame().sort_values(by = 'Avg Salary',ascending = False)
# Out:
#                  Avg Salary
# Location
# Bellevue           184.5000
# Lake Forest        179.5000
# Mountain View      177.1875
# Novato             168.0000
# Burbank            164.0000
# ...                     ...
# West Reading        41.0000
# Kansas City         40.5000
# Alabaster           39.5000
# Longmont            29.5000
# Port Washington     15.5000
#
# [195 rows x 1 columns]

# %%
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Per hour', 'Min Salary', 'Max Salary', 'Avg Salary', 'Same place',
#        'age', 'Python', 'Power bi', 'Excel', 'Aws', 'Title', 'position',
#        'num_compi'],
#       dtype='object')

# %%
cols_for_grp = ['Rating',
       'Company Name', 'Location', 'Headquarters', 'Size', 'Type of ownership', 'Industry', 'Sector', 'Revenue','Same place',
       'age', 'Python', 'Power bi', 'Excel', 'Aws', 'Title', 'position',
       'num_compi']

# %%
for i in cols_for_grp:
    print("")
    print("")
    print(i)
    print(data.groupby(i)['Avg Salary'].mean().to_frame().sort_values(by = 'Avg Salary', ascending = False))
# Out:
# Rating
#           Avg Salary
# Rating
# 3.618868  136.181818
# 5.000000  134.700000
# 2.500000  120.000000
# 4.500000  117.714286
# 4.100000  116.368421
# 3.900000  113.071429
# 2.600000  109.083333
# 4.400000  108.606061
# 4.000000  107.170213
# 3.200000  106.928571
# 3.700000  105.680328
# 3.500000  104.897959
# 4.700000  103.983871
# 3.300000  103.897436
# 4.300000  102.468750
# 4.200000  100.442308
# 2.200000   97.750000
# 3.800000   97.418033
# 4.600000   97.250000
# 2.100000   95.900000
# 3.400000   93.465909
# 3.600000   89.945652
# 1.900000   87.500000
# 3.100000   86.580000
# 3.000000   85.588235
# 2.700000   85.178571
# 2.800000   83.928571
# 2.300000   81.500000
# 2.900000   81.138889
# 4.800000   80.277778
# 2.400000   60.214286
#
#
# Company Name
#                          Avg Salary
# Company Name
# Gallup                        237.5
# Sage Intacct                  232.5
# CA-One Tech C                 225.0
# Grand Rounds                  221.5
# ...
